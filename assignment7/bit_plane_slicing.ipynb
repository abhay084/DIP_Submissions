# %%
import matplotlib.pyplot as plt
import matplotlib.image as mping
import numpy as np

# %%
img = mping.imread('img.jpg')

# %%
# original image
plt.imshow(img)
plt.show()

# %%
np.shape(img)
# Out:
# (235, 324, 3)

# %%
import cv2

# %%
gray_img = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
np.shape(gray_img)
# Out:
# (235, 324)

# %%
type(gray_img)
# Out:
# numpy.ndarray

# %%
plt.imshow(gray_img,cmap='gray')
plt.show()

# %%
plane0=np.zeros((235, 324))
plane1=np.zeros((235, 324))
plane2=np.zeros((235, 324))
plane3=np.zeros((235, 324))
plane4=np.zeros((235, 324))
plane5=np.zeros((235, 324))
plane6=np.zeros((235, 324))
plane7=np.zeros((235, 324))

# %%
def get_binary(num):
    m=bin(num).replace('0b','')
    x=m[::-1]
    while(len(x)<8):
        x+='0'
    m=x[::-1]
    return m

# %%
binary_val=np.zeros((235,324))

# %%
for i in range(235):
    for j in range(324):
        x = gray_img[i][j]
        binary_val[i][j]=get_binary(x)

# %%
binary_val1=binary_val.astype(int)

# %%
binary_val1[3][5]
# Out:
# 11001011

# %%
np.shape(binary_val1)
# Out:
# (235, 324)

# %%
for i in range(235):
    for j in range(324):
        val=int(binary_val1[i][j])
        x = str(val)
        plane0[i][]

# %%
x
# Out:
# '110001'
